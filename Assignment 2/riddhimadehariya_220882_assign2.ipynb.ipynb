# %% [markdown]
# **Fill the Code blocks according to the comments provided as hints**

# %%
from sklearn.datasets import load_diabetes #We will use this dataset

#import libraries for numpy, Linear regression, r2_score, train_test_split
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
X,y = load_diabetes(return_X_y=True)  #loading dataset

# %%
diabetes_data = load_diabetes()
df = pd.DataFrame(data=diabetes_data.data, columns=diabetes_data.feature_names)
df['target'] = diabetes_data.target
df
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6  target
# 0   -0.002592  0.019907 -0.017646   151.0
# 1   -0.039493 -0.068332 -0.092204    75.0
# 2   -0.002592  0.002861 -0.025930   141.0
# 3    0.034309  0.022688 -0.009362   206.0
# 4   -0.002592 -0.031988 -0.046641   135.0
# ..        ...       ...       ...     ...
# 437 -0.002592  0.031193  0.007207   178.0
# 438  0.034309 -0.018114  0.044485   104.0
# 439 -0.011080 -0.046883  0.015491   132.0
# 440  0.026560  0.044529 -0.025930   220.0
# 441 -0.039493 -0.004222  0.003064    57.0
#
# [442 rows x 11 columns]

# %%
#print shape of X and y and write in a text block what do you observe about both 
print(X.shape)
print(y.shape)
# Out:
# (442, 10)
# (442,)

# %%
#split the dataset into Train(80%) and Test(20%)

from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
#fit X,y in Linear Regression Model of sklearn
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
X = X.reshape(-1, 1)
lin_reg.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
#print coefficients and intercepts (in @d gradient descent in was only m and b but as it is n dimensional it will have n coefficients and 1 intercept)

print("Coefficients:")
for feature_name, coef in zip(diabetes_data.feature_names, lin_reg.coef_):
    print(f"{feature_name}: {coef}")
# Print the intercept (bias)
print("Intercept:")
print(lin_reg.intercept_)
# Out:
# Coefficients:
# age: -35.55025079114186
# sex: -243.1650895885525
# bmi: 562.7623474355647
# bp: 305.4634821756327
# s1: -662.7029008904819
# s2: 324.2073853668423
# s3: 24.74879488572692
# s4: 170.32496150376048
# s5: 731.6374354481421
# s6: 43.03093069644549
# Intercept:
# 152.5380470138517

# %%
#predict on X_test and calculate r2_score

y_pred = lin_reg.predict(X_test)
from sklearn.metrics import r2_score
r2 = r2_score(Y_test, y_pred)
print(f"R-squared score: {r2}")
# Out:
# R-squared score: 0.3322332173106184

# %%
#print X_train shape
print (X_train.shape)
# Out:
# (353, 10)

# %%
#Write GDregressor class


class GDRegressor:
    
    def __init__(self,learning_rate,epochs):
        
        self.coef_ = None
        self.intercept_ = None
        self.lr = learning_rate
        self.epochs = epochs
        
    def fit(self,X_train,y_train):
        # init your coefs
        num_samples, num_features = X_train.shape
        self.intercept_ = np.zeros(1) #initialise the intercept
        self.coef_ = np.zeros(num_features) #initialise the array of coefficients according to number of coefficients
        
        for i in range(self.epochs):
            y_pred = self.predict(X_train)
            # update all the coef and the intercept
            


            y_hat =self.coef_ *X + self.intercept_ #apply prediction formula i.e. (y_hat = coefficient*X + intercept) in terms of matrices coefficient and X   
            intercept_derivative =  np.mean(y_pred - y_train)#find derivative matrix 
            self.intercept_ = self.lr * intercept_derivative #update intercept using above intercept_derivative
            
            coef_derivative = np.dot(X_train.T, (y_pred - y_train)) / num_samples #derivative matrix for all coefficients in a single step
            self.coef_ = self.lr * coef_derivative#update intercept using coef_derivative
        
        #print the coefficients array and the intercept
    def print_coefficients(self):
        print("Coefficients:")
        print(self.weights)

    def print_intercept(self):
        print("Intercept:")
        print(self.bias)
    
    def predict(self,X_test):
        return np.dot(X_test, self.coef_) + self.intercept_ #new prediction in the form of (y = coefficients*X + intercept) using matrices

# %%
#call GDRegressor by keeping epochs and learning rate according to you and keep changing it for better results

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

print(type(X_scaled))
# Create an instance of GDRegressor with initial hyperparameters
learning_rate = 0.01
epochs = 1000
regressor = GDRegressor(learning_rate, epochs)
# Out:
# <class 'numpy.ndarray'>

# %%
#fit X_train, y_train into GDRegressor object using function of the class
regressor.fit(X_train, Y_train)

# %%
#predict on X_test using function of the class
y_pred = regressor.predict(X_test)

# %%
#calculate r2_score to verify
r2 = r2_score(Y_test, y_pred)
print("R2 Score:", r2)
# Out:
# R2 Score: -4.731009922599815
