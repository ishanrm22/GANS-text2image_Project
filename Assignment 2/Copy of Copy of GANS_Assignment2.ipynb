# %% [markdown]
# **Fill the Code blocks according to the comments provided as hints**

# %%
from sklearn.datasets import load_diabetes #We will use this dataset

#import libraries for numpy, Linear regression, r2_score, train_test_split
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
X,y = load_diabetes(return_X_y=True)  #loading dataset

# %%
#print shape of X and y and write in a text block what do you observe about both 
shape_X = X.shape
print("Shape of X is",shape_X)
shape_y = y.shape
print("Shape of y is",shape_y)
# Out:
# Shape of X is (442, 10)
# Shape of y is (442,)

# %% [markdown]
# X is a 2D array.
# And y is a 1D array.

# %%
#split the dataset into Train(80%) and Test(20%)

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.8, random_state=9 )

# %%
#fit X,y in Linear Regression Model of sklearn

Linear_regression_model = LinearRegression()
Linear_regression_model.fit(X, y)
# Out:
# LinearRegression()

# %%
#print coefficients and intercepts (in @d gradient descent in was only m and b but as it is n dimensional it will have n coefficients and 1 intercept)

coeff = Linear_regression_model.coef_
intercept = Linear_regression_model.intercept_

print("Coefficients of the model are ", coeff)
print("Intercept of the model is ", intercept)
# Out:
# Coefficients of the model are  [ -10.0098663  -239.81564367  519.84592005  324.3846455  -792.17563855
#   476.73902101  101.04326794  177.06323767  751.27369956   67.62669218]
# Intercept of the model is  152.13348416289597

# %%
#predict on X_test and calculate r2_score

predicted_y = Linear_regression_model.predict(X_test)
r2 = r2_score(y_test, predicted_y)

print("The r2 score for the above data:", r2)
# Out:
# The r2 score for the above data: 0.6095361022963277

# %%
#print X_train shape
shape_X_train = X_train.shape
print("Shape of X_train is",shape_X_train)
# Out:
# Shape of X_train is (353, 10)

# %%
#Write GDregressor class


class GDRegressor:
    
    def __init__(self,learning_rate,epochs):
        
        self.coef_ = None
        self.intercept_ = None
        self.lr = learning_rate
        self.epochs = epochs
        
    def fit(self,X_train,y_train):
        # init your coefs
        self.intercept_ = 0.0                                                   #initialise the intercept
        self.coef_ = np.zeros(X_train.shape[1])                                 #initialise the array of coefficients according to number of coefficients
        
        for i in range(self.epochs):
        # update all the coef and the intercept
            y_hat = np.dot(X_train, self.coef_) + self.intercept_               #apply prediction formula i.e. (y_hat = coefficient*X + intercept) in terms of matrices coefficient and X   
            intercept_derivative = -2 * np.mean(y_train - y_hat)                #find derivative matrix 
            self.intercept_ -=(self.lr * intercept_derivative)                  #update intercept using above intercept_derivative
            
            coef_derivative = -2 * np.dot(X_train.T, y_train - y_hat) / len(X_train)#derivative matrix for all coefficients in a single step
            self.coef_ -=(self.lr * coef_derivative)                            #update intercept using coef_derivative
        
        #print the coefficients array and the intercept

        print("The Coefficients array is", self.coef_)
        print("The Intercept is", self.intercept_)
    
    def predict(self,X_test):
        return np.dot(X_test, self.coef_) + self.intercept_
    #new prediction in the form of (y = coefficients*X + intercept) using matrices

# %%
#call GDRegressor by keeping epochs and learning rate according to you and keep changing it for better results

learning_rates = [0.1]
epochs = [5000, 10000]

for lr in learning_rates:
  for epoch in epochs:
    GD_Regressor = GDRegressor(lr, epoch)

# %%
#fit X_train, y_train into GDRegressor object using function of the class

GD_Regressor.fit(X_train, y_train)
# Out:
# The Coefficients array is [  -8.40529586 -257.4251531   470.13803778  338.05740921  -58.6632749
#   -85.2184967  -228.41072646  126.1727788   475.1235434    80.11214792]
# The Intercept is 153.05375587620398

# %%
#predict on X_test using function of the class

Prediction_on_X_test = GD_Regressor.predict(X_test)
print(Prediction_on_X_test)
# Out:
# [ 74.71071045 103.77482386 199.94005303 124.67163844 111.73648159
#  247.99414272 212.32580275 132.1073798  127.70309551  63.74376171
#   49.34427748 134.96108014 147.58337943 271.85766628  88.38909118
#   78.60169493 170.20625742  86.72072753 122.92446682 187.12660719
#  147.75525337  84.18372183 251.97536877 142.09728793  79.05578494
#  165.42992154 177.42742018 114.14039487  83.64105037 295.71763829
#  234.64919721 256.62182434 249.22304984 222.47223252 125.22758806
#  108.15445759 162.65023511 122.69710438 185.55221791 162.07495042
#   89.46037735 147.20346048 181.17051747  86.86881756 189.85472811
#  111.51687429  76.14461571  78.43853932 184.24042103 148.34220925
#  103.98204185 121.8082415   79.74400382  90.14320527 165.05495519
#  106.54757096 118.84297653 211.53899021 157.37797015 209.8326522
#  174.65041823 176.68201662 161.56646807 216.12516237  99.76493457
#  142.09521225 193.42287453  70.52907404  63.93702271 175.89469182
#  276.73819882 162.69358001 227.72501942  68.95795576 133.0850375
#  148.73582825  82.33497116 266.51843578 115.96013827 246.54454761
#  126.09925071 169.99916371 143.29073882 199.31118182 142.98332087
#   62.22825204 160.89898448 115.31864817 205.38412104]

# %%
#calculate r2_score to verify

previous_R2 = (r2)
print("Previous R2 score:", previous_R2)

R2 = r2_score(y_test, Prediction_on_X_test)
print("R2 score:", R2)
# Out:
# Previous R2 score: 0.6095361022963277
# R2 score: 0.6000551478507244
